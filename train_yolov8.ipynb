# %%
from roboflow import Roboflow

# Initialize with your API key
rf = Roboflow(api_key="bzUthNVUoOi1lCw5weyO")  # ✅ Your Roboflow API key

# Connect to your project and version
project = rf.workspace("accident-detection-model").project("accident-detection-model")
version = project.version(2)

# Download dataset in YOLOv8 format
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to Accident-detection-model-2 in yolov8:: 100%|██████████| 6512/6512 [00:56<00:00, 115.71it/s]

# %%
import torch

# Check if CUDA is available
if torch.cuda.is_available():
    print("✅ CUDA is available!")
    print(f"GPU Device Name: {torch.cuda.get_device_name(0)}")
    print(f"Number of GPUs: {torch.cuda.device_count()}")
else:
    print("❌ CUDA is NOT available. Using CPU.")
# Out:
# ✅ CUDA is available!
# GPU Device Name: NVIDIA GeForce RTX 3050 Laptop GPU
# Number of GPUs: 1

# %%
from ultralytics import YOLO

# Load a YOLOv8 model (you can use 'yolov8n', 'yolov8s', etc.)
model = YOLO("yolov8n.pt")

# Train with your dataset
results = model.train(data="accident-detection-model-2/data.yaml", epochs=50, imgsz=640)
# Out:
# Ultralytics 8.3.171  Python-3.12.2 torch-2.5.1+cu121 CUDA:0 (NVIDIA GeForce RTX 3050 Laptop GPU, 4096MiB)
# ...

# %%
from ultralytics import YOLO

# Load the trained model
model = YOLO("runs/detect/train4/weights/best.pt")

# Run inference on an image or video
results = model(
    r"C:/Road-Accident-Detection-Alert-System-main/datasets/test/images/Accidents-online-video-cutter_com-_mp4-74_jpg.rf.c9a73363436bfd4eec233af8c9839319.jpg",
    save=True,
)  # save=True saves results
# Out:
# image 1/1 C:\Road-Accident-Detection-Alert-System-main\datasets\test\images\Accidents-online-video-cutter_com-_mp4-74_jpg.rf.c9a73363436bfd4eec233af8c9839319.jpg: 640x640 1 Accident, 62.0ms
# Speed: 4.9ms preprocess, 62.0ms inference, 2.9ms postprocess per image at shape (1, 3, 640, 640)
# Results saved to runs\detect\predict3
